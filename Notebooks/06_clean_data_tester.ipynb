# %%
# Working directory set
import sys
sys.path.append("../scripts/")

# %%
import pandas as pd
import numpy as np
import json
import seaborn as sns

from clean_data import load_and_clean_data

pd.set_option('display.max_rows', 400)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc

def run_baseline_dt(X_train, y_train):

    # 70 20 10 split
    # X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .1, random_state = 42)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = .25, random_state = 42)
    
    dt = DecisionTreeClassifier()
    dt.fit(X_train, y_train)
    y_pred = dt.predict_proba(X_val)[:,1]
    
    fpr, tpr, thresholds = roc_curve(y_val, y_pred)
    roc_auc = auc(fpr, tpr)
    
    importances = {}
    for name, importance in zip(X_val.columns, dt.feature_importances_):
        importances[name] = importance
        
    imp = pd.DataFrame.from_dict(importances, orient = 'index', columns = ['importance'])
    imp.sort_values(by = 'importance', ascending = False, inplace = True)
    
    return fpr, tpr, roc_auc, imp

# %%
X_train, X_test, y_train, y_test = load_and_clean_data()
# Out:
# /var/folders/dp/df65_q2x4lv3t41057t55p780000gn/T/ipykernel_55209/285054500.py:1: DtypeWarning: Columns (10,17,19,23,25,27,28,29,30,32,33,36,37,38,39,40,41,42,43,50,51,83,86,89,92,94,95,97,100,103,106,110,113,116,121,124,127,130,133,136,188,190,201,212,231,232,242,244,247,249,256,262,267,273,279,280,281,282,283,284,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,305,318,320,333,334) have mixed types.Specify dtype option on import or set low_memory=False.
#   X_train, X_test, y_train, y_test = load_and_clean_data()
# /Users/kpant/.pyenv/versions/3.9.1/envs/cs/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# ../scripts/clean_data.py:262: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['insulin'] = df.DIABETES  # Duplicate diabetes column for one-hot encoding
# /Users/kpant/.pyenv/versions/3.9.1/envs/cs/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# /Users/kpant/.pyenv/versions/3.9.1/envs/cs/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
nulls = [col for col in data.columns if (data[col].isnull().sum() != 0)]
nulls

# %%
fpr, tpr, roc_auc, imp = run_baseline_dt(X_train, y_train)

# %%
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)

# %%
roc_auc
# Out:
# 0.620010731975891

# %%
imp
# Out:
#                        importance
# DOPTODIS                 0.099047
# MORBPROB                 0.050179
# RETURNOR                 0.043052
# OPTIME                   0.039844
# bmi                      0.037811
# MORTPROB                 0.036959
# PRWBC                    0.034147
# PRHCT                    0.034000
# PRPLATE                  0.033699
# PRCREAT                  0.033149
# PRBUN                    0.025697
# ORGSPCSSI                0.025391
# AGE                      0.025056
# PRSODM                   0.022149
# COL_ILEUS_1              0.018782
# COL_ANASTOMOTIC_1        0.016106
# TOTHLOS                  0.015735
# WORKRVU                  0.011616
# REOPERATION1             0.011275
# num_other_procs          0.010528
# HTOODAY                  0.009175
# ADMQTR                   0.009168
# PUFYEAR                  0.009014
# OPERYR                   0.008720
# COL_ANASTOMOTIC_2        0.007546
# RETORRELATED_2           0.007067
# OSSIPATOS                0.005500
# num_concurr_procs        0.005437
# female                   0.004418
# STEROID                  0.004027
# DIGESTIVE                0.004017
# COL_ORAL_ANTIBIOTIC_1    0.003822
# SM_INT                   0.003810
# OTHBLEED                 0.003797
# COL_MECH_BOWEL_PREP_1    0.003749
# PRNCPTX_3                0.003666
# HYPERMED                 0.003550
# PRNCPTX_9                0.003358
# PERITONEUM               0.003121
# WNDCLAS_1                0.003076
# UROGENITAL               0.003073
# COL_ORAL_ANTIBIOTIC_2    0.002966
# DISCHDEST_8              0.002920
# COL_CHEMO_1              0.002896
# COL_MECH_BOWEL_PREP_2    0.002770
# ASACLAS_2                0.002767
# ELECTSURG_1              0.002655
# K57                      0.002618
# WNDCLAS_3                0.002581
# COL_NODESEVAL_1          0.002498
# SMOKE                    0.002494
# PROCTOLOGY               0.002458
# URNINFEC                 0.002416
# DYSPNEA_2                0.002404
# PRNCPTX_10               0.002392
# WNDCLAS_2                0.002340
# K63                      0.002293
# HXCOPD                   0.002288
# COL_MALIGNANCYT_2        0.002269
# ASACLAS_1                0.002263
# BLEEDIS_2                0.002221
# C18                      0.002201
# insulin                  0.002198
# COL_NODESEVAL_6          0.002150
# K50                      0.002140
# PRNCPTX_2                0.002125
# COL_MALIGNANCYM_5        0.002100
# OTHCDIFF_2               0.002052
# HEP_PAN_BIL              0.002051
# DISCHDEST_6              0.002020
# RENAINSF                 0.001989
# BLEEDIS_1                0.001969
# COL_APPROACH_2           0.001950
# DYSPNEA_1                0.001915
# PRSEPIS_1                0.001889
# COL_MALIGNANCYN_9        0.001879
# DISCANCR                 0.001869
# COL_NODESEVAL_16         0.001854
# COL_NODESEVAL_13         0.001851
# COL_NODESEVAL_47         0.001849
# SUPINFEC                 0.001767
# COL_NODESEVAL_36         0.001749
# COL_NODESEVAL_69         0.001742
# COL_NODESEVAL_9          0.001741
# ASACLAS_3                0.001738
# K56                      0.001738
# COL_MALIGNANCYT_4        0.001731
# UTIPATOS                 0.001726
# COL_NODESEVAL_10         0.001721
# PRNCPTX_5                0.001701
# SEPSISPATOS              0.001687
# WTLOSS                   0.001674
# COL_MALIGNANCYT_1        0.001672
# diabetes                 0.001658
# C20                      0.001655
# COL_MALIGNANCYT_3        0.001654
# CDMI                     0.001644
# COL_NODESEVAL_12         0.001642
# COL_NODESEVAL_14         0.001626
# EMERGNCY                 0.001621
# COL_ANASTOMOTIC_5        0.001595
# COL_MALIGNANCYM_1        0.001592
# COL_NODESEVAL_18         0.001573
# COL_MALIGNANCYT_9        0.001572
# COL_ANASTOMOTIC_4        0.001561
# COL_NODESEVAL_25         0.001546
# WOUND_CLOSURE_3          0.001541
# COL_NODESEVAL_11         0.001533
# K59                      0.001525
# COL_NODESEVAL_21         0.001524
# D12                      0.001516
# COL_NODESEVAL_7          0.001501
# COL_NODESEVAL_3          0.001496
# COL_NODESEVAL_2          0.001487
# WOUND_CLOSURE_2          0.001476
# DISCHDEST_3              0.001459
# COL_MALIGNANCYN_7        0.001417
# RESP                     0.001415
# C19                      0.001410
# COL_MALIGNANCYN_3        0.001400
# COL_NODESEVAL_19         0.001394
# TRANST_1                 0.001370
# COL_ANASTOMOTIC_7        0.001360
# OTHSESHOCK               0.001358
# COL_MALIGNANCYN_1        0.001347
# COL_MARGINS_2            0.001331
# PRNCPTX_8                0.001329
# C78                      0.001326
# TRANST_3                 0.001325
# OTHDVT                   0.001304
# SSSIPATOS                0.001284
# COL_ANASTOMOTIC_3        0.001277
# COL_MALIGNANCYN_6        0.001271
# COL_NODESEVAL_20         0.001263
# COL_MALIGNANCYN_2        0.001255
# K55                      0.001241
# PRNCPTX_7                0.001238
# K51                      0.001231
# WNDINFD                  0.001230
# DEHIS                    0.001225
# OTHSYSEP                 0.001183
# HXCHF                    0.001183
# COL_NODESEVAL_22         0.001162
# COL_MALIGNANCYM_2        0.001145
# COL_NODESEVAL_80         0.001138
# COL_NODESEVAL_15         0.001133
# DSSIPATOS                0.001127
# COL_NODESEVAL_91         0.001118
# INTEGUMENTARY            0.001117
# COL_NODESEVAL_5          0.001117
# ENDOCRINE                0.001109
# FNSTATUS2_1              0.001108
# OUPNEUMO                 0.001104
# COL_NODESEVAL_8          0.001089
# COL_CHEMO_2              0.001084
# PRSEPIS_2                0.001082
# COL_MALIGNANCYN_5        0.001080
# ASCITES                  0.001073
# COL_NODESEVAL_58         0.001034
# PRNCPTX_1                0.001013
# DISCHDEST_2              0.001013
# FAILWEAN                 0.000998
# COL_NODESEVAL_26         0.000986
# COL_NODESEVAL_17         0.000969
# COL_NODESEVAL_27         0.000962
# Z43                      0.000961
# K91                      0.000959
# COL_NODESEVAL_28         0.000957
# COL_NODESEVAL_33         0.000948
# MED_EVAL                 0.000945
# PRNCPTX_6                0.000936
# COL_MALIGNANCYN_4        0.000934
# PULEMBOL                 0.000907
# COL_NODESEVAL_23         0.000901
# COL_MALIGNANCYT_6        0.000894
# WNDINF                   0.000880
# COL_MALIGNANCYT_5        0.000879
# OTHCDIFF_1               0.000879
# STOMACH                  0.000873
# TRANST_2                 0.000854
# COL_ANASTOMOTIC_9        0.000853
# COL_ANASTOMOTIC_6        0.000850
# TRANST_4                 0.000845
# K65                      0.000840
# A41                      0.000839
# OTHER                    0.000838
# COL_MALIGNANCYT_8        0.000820
# COL_NODESEVAL_102        0.000804
# inpatient                0.000797
# N82                      0.000797
# COL_MALIGNANCYN_8        0.000796
# COL_NODESEVAL_32         0.000784
# COL_NODESEVAL_34         0.000773
# COL_NODESEVAL_24         0.000762
# COL_MALIGNANCYM_3        0.000754
# FNSTATUS2_3              0.000729
# COL_NODESEVAL_39         0.000710
# K62                      0.000697
# ASACLAS_4                0.000689
# FNSTATUS2_2              0.000689
# K35                      0.000683
# DISCHDEST_7              0.000674
# REINTUB                  0.000673
# TRANSFUS                 0.000643
# TRANST_5                 0.000634
# COL_NODESEVAL_35         0.000630
# REOPERATION2             0.000619
# COL_NODESEVAL_29         0.000614
# ANESTHES_5               0.000585
# COL_NODESEVAL_30         0.000583
# COL_NODESEVAL_38         0.000582
# COL_MALIGNANCYM_4        0.000581
# MUSCULOSKELETAL          0.000558
# SURGSPEC_11              0.000557
# N32                      0.000548
# WOUND_CLOSURE_1          0.000545
# C7A                      0.000541
# SEPSHOCKPATOS            0.000520
# K52                      0.000508
# ANESTHES_1               0.000505
# K43                      0.000503
# COL_MARGINS_1            0.000495
# C56                      0.000488
# COL_MALIGNANCYT_7        0.000487
# MECKEL                   0.000459
# COL_NODESEVAL_40         0.000455
# D37                      0.000450
# COL_ILEUS_2              0.000440
# K94                      0.000435
# SURGSPEC_1               0.000426
# OPRENAFL                 0.000409
# COL_NODESEVAL_37         0.000407
# PNAPATOS                 0.000406
# ASACLAS_5                0.000403
# COL_NODESEVAL_57         0.000397
# PRNCPTX_4                0.000394
# SURGSPEC_10              0.000386
# DIALYSIS                 0.000386
# DISCHDEST_9              0.000378
# R19                      0.000373
# COL_NODESEVAL_41         0.000362
# STILLINHOSP              0.000357
# COL_NODESEVAL_45         0.000344
# COL_NODESEVAL_31         0.000330
# RETORRELATED_1           0.000320
# SURGSPEC_2               0.000320
# D49                      0.000315
# ELECTSURG_2              0.000305
# K92                      0.000291
# ANESTHES_7               0.000282
# COL_NODESEVAL_51         0.000280
# D01                      0.000275
# VENTPATOS                0.000258
# CNSCVA                   0.000257
# COL_NODESEVAL_4          0.000252
# COL_NODESEVAL_44         0.000251
# PRSEPIS_4                0.000248
# D3A                      0.000242
# PRSEPIS_3                0.000238
# RENAFAIL                 0.000235
# COL_NODESEVAL_48         0.000222
# DISCHDEST_10             0.000221
# COL_NODESEVAL_46         0.000206
# K38                      0.000203
# CDARREST                 0.000201
# C48                      0.000193
# COL_NODESEVAL_43         0.000193
# COL_NODESEVAL_49         0.000190
# C49                      0.000185
# A04                      0.000176
# VENTILAT                 0.000152
# DISCHDEST_5              0.000151
# SURGSPEC_7               0.000129
# COL_NODESEVAL_66         0.000128
# COL_NODESEVAL_61         0.000128
# COL_NODESEVAL_65         0.000126
# COL_NODESEVAL_71         0.000122
# COL_NODESEVAL_74         0.000121
# DISCHDEST_1              0.000121
# COL_NODESEVAL_72         0.000121
# COL_NODESEVAL_42         0.000120
# COL_NODESEVAL_56         0.000111
# COL_NODESEVAL_53         0.000110
# COL_NODESEVAL_55         0.000099
# C17                      0.000096
# COL_NODESEVAL_60         0.000093
# COL_NODESEVAL_64         0.000091
# ORO_ESOPH                0.000090
# COL_NODESEVAL_52         0.000080
# COL_APPROACH_3           0.000073
# COL_NODESEVAL_78         0.000070
# COL_NODESEVAL_76         0.000069
# COL_NODESEVAL_82         0.000068
# COL_NODESEVAL_86         0.000066
# SURGSPEC_5               0.000065
# COL_NODESEVAL_85         0.000065
# ANESTHES_6               0.000064
# COL_NODESEVAL_70         0.000064
# COL_NODESEVAL_68         0.000063
# ANESTHES_4               0.000063
# SURGSPEC_9               0.000062
# COL_NODESEVAL_81         0.000062
# ANESTHES_3               0.000062
# DISCHDEST_4              0.000060
# SURGSPEC_8               0.000060
# COL_NODESEVAL_73         0.000059
# COL_NODESEVAL_54         0.000058
# COL_NODESEVAL_75         0.000057
# COL_NODESEVAL_67         0.000031
# COL_NODESEVAL_63         0.000030
# COL_APPROACH_1           0.000029
# COL_NODESEVAL_62         0.000012
# COL_NODESEVAL_50         0.000010
# COL_NODESEVAL_89         0.000000
# COL_NODESEVAL_98         0.000000
# COL_NODESEVAL_97         0.000000
# COL_NODESEVAL_99         0.000000
# COL_NODESEVAL_96         0.000000
# COL_NODESEVAL_95         0.000000
# COL_NODESEVAL_100        0.000000
# COL_NODESEVAL_94         0.000000
# COL_NODESEVAL_93         0.000000
# COL_NODESEVAL_92         0.000000
# COL_NODESEVAL_101        0.000000
# COL_NODESEVAL_90         0.000000
# COL_NODESEVAL_59         0.000000
# COL_NODESEVAL_88         0.000000
# COL_NODESEVAL_87         0.000000
# COL_ANASTOMOTIC_8        0.000000
# COL_NODESEVAL_84         0.000000
# COL_NODESEVAL_83         0.000000
# ANESTHES_2               0.000000
# COL_NODESEVAL_79         0.000000
# COL_NODESEVAL_77         0.000000
# SURGSPEC_12              0.000000
# SURGSPEC_3               0.000000
# SURGSPEC_6               0.000000
# ANESTHES_8               0.000000
# SURGSPEC_4               0.000000
